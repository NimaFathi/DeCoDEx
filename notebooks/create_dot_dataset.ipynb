# %% [markdown]
# # Dot Dataset
#
# In this notebook we add the dot artifact to cheXpert dataset.
#
# First you should download the dataset from <a href="https://www.kaggle.com/datasets/willarevalo/chexpert-v10-small">here</a>.

# %%
import os
import sys
project_root= '../'
sys.path.append(project_root)

# %% [markdown]
# # Load Required Libraries

# %%
import pandas as pd
import random
import os
import shutil
import csv
from sklearn.model_selection import train_test_split
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# In here we filter out the images and exclude PA images.

# %%
train_df = pd.read_csv('/usr/local/faststorage/datasets/chexpert/train.csv')

train_df = train_df[train_df['Frontal/Lateral']=='Frontal' ]
train_df = train_df.reset_index(drop=True)

# %% [markdown]
# In the next part, we further filter out images with No Finding and Pleural Effusion while making sure that the Support Devices are not visible in the resulted dataset.

# %%
import pandas as pd

info_path = '../datasets/dot_90/info.csv'

# Create parent directories for the file if they do not exist
os.makedirs(os.path.dirname(info_path), exist_ok=True)
# Load the original CSV file
chexpert_data = train_df

# Define a function to determine the health status with the updated criteria
def determine_health_status_final(row):
    if row['No Finding'] == 1.0 and row['Frontal/Lateral'] == 'Frontal' and row['Support Devices'] == 0.0:
        return 1  # Healthy
    elif row['Pleural Effusion'] == 1.0 and row['Frontal/Lateral'] == 'Frontal' and row['Support Devices'] == 0.0:
        return -1  # Unhealthy
    else:
        return None  # None for other cases


chexpert_data['Healthy/Unhealthy'] = chexpert_data.apply(determine_health_status_final, axis=1)

# Drop rows where 'Healthy/Unhealthy' is None
filtered_data_final = chexpert_data.dropna(subset=['Healthy/Unhealthy'])

# Selecting the specified columns
filtered_data_final = filtered_data_final[['Path', 'Sex', 'Age', 'Frontal/Lateral', 'AP/PA', 'Support Devices','Healthy/Unhealthy']]

# Save the new DataFrame to a CSV file
output_file_path_final = info_path # Replace with your desired output file path
filtered_data_final.to_csv(output_file_path_final, index=False)

# Print completion message
print("CSV file has been created at:", output_file_path_final)
# Out:
# CSV file has been created at: ../datasets/dot_90/info.csv

# %% [markdown]
# # Grouping
#
# Here we define our groupings:
#
# - group 0: This group denotes the subjects with Pleural Effusion and the artifact. (Contains 90% of the unhealthy subjects)
# - group 1: This group denotes the subjects with No Finding and the artifact. (Contains 10% of the healthy subjects)
# - group 2: This group denotes the subjects with Pleural Effusion and No artifact. (Contains 10% of the unhealthy subjects)
# --group 3: This group denotes the subjects with No Finding and No artifact. (Contains 90% of the healthy subjects)

# %%
import pandas as pd
import numpy as np
# Load your CSV file
file_path = info_path  # Replace with the path to your filtered CSV file
data = pd.read_csv(file_path)

# Initialize a new 'group' column
data['group'] = np.nan

# Set a random seed for reproducibility
np.random.seed(0)

# Assign groups based on health status and random chance
for index, row in data.iterrows():
    if row['Healthy/Unhealthy'] == -1:  # Unhealthy
        if np.random.rand() < 0.9:
            data.at[index, 'group'] = 0
        else:
            data.at[index, 'group'] = 2 
    elif row['Healthy/Unhealthy'] == 1:  # Healthy
        if np.random.rand() < 0.9:
            data.at[index, 'group'] = 3
        else:
            data.at[index, 'group'] = 1 

# Save the updated DataFrame to a new CSV file
updated_csv_path = info_path  # Replace with your desired output file path
data.to_csv(updated_csv_path, index=False)

# %% [markdown]
# Here we modify the path column. There is not any specific reason for this just a personal choice of the author.

# %%
# Function to modify the 'Path' values
def modify_path(path):
    parts = path.split('/')
    new_path = '_'.join(parts[1:])  # Join parts excluding the first element (usually the dataset name)
    return new_path

# Apply the function to the 'Path' column
data['Path'] = data['Path'].apply(modify_path)

# Save the updated DataFrame to a new CSV file
updated_csv_path = info_path  # Replace with your desired output file path
data.to_csv(updated_csv_path, index=False)

print("Updated CSV file saved to:", updated_csv_path)
# Out:
# Updated CSV file saved to: ../datasets/dot_90/info.csv

# %% [markdown]
# # Adding Artifact
# Here we add the artifact to the designated images and save the new dataset (images) for reproducablity.
#
# Note: If you don't have enough space to do so you can always save the info.csv file and add the circle on-the-fly in your dataloader.

# %%
from PIL import Image, ImageDraw
import os
import shutil

def add_black_circle_to_image(input_image_path, circle_radius):
    with Image.open(input_image_path) as img:
        if img.mode != 'L':
            img = img.convert('L')
        draw = ImageDraw.Draw(img)
        width, height = img.size
        center = (width // 2, height // 2)
        draw.ellipse([center[0] - circle_radius, center[1] - circle_radius, 
                      center[0] + circle_radius, center[1] + circle_radius], fill='black')
        return img

# Load the updated CSV file
csv_file_path = info_path  # Replace with your updated CSV file path
data = pd.read_csv(csv_file_path)

# Set the paths
original_images_folder = '/usr/local/faststorage/datasets/chexpert/img_chexpert'  # Replace with your original dataset path
new_images_folder = '../datasets/dot_90/imgs'
os.makedirs(new_images_folder, exist_ok=True)

# Process the images
circle_radius = 9  # Set the circle radius

for index, row in data.iterrows():
    try: 
        original_image_path = os.path.join(original_images_folder, row['Path'])
        new_image_path = os.path.join(new_images_folder, row['Path'])
        print(new_image_path)
        if row['group'] in [0, 1]:  # Add a circle for groups 0 and 1
            img_with_circle = add_black_circle_to_image(original_image_path, circle_radius)
            img_with_circle.save(new_image_path)
        else:  # Copy the image as is for groups 2 and 3
            shutil.copyfile(original_image_path, new_image_path)
    except:
        # drop the row from the dataframe
        data = data.drop(index)
        print('error')
        continue
# Save the updated DataFrame to a new CSV file
updated_csv_path = info_path  # Replace with your desired output file path
data.to_csv(updated_csv_path, index=False)
print("Images processed and saved in", new_images_folder)
# Out:
# ../datasets/dot_90/imgs/train_patient00019_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00062_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00084_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00128_study12_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00134_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00134_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00165_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00169_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00175_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00177_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00204_study16_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00216_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00255_study13_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00256_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00277_study13_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00286_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00287_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00312_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00314_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00314_study8_view2_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00314_study29_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00314_study28_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00319_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00326_study19_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00370_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00421_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00457_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00467_study40_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00537_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00611_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00611_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00625_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00669_study10_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00696_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00701_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00742_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00750_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00754_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00770_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00771_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00773_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00784_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00865_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00865_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00865_study11_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00877_study16_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00877_study17_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient00992_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01018_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01018_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01046_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01071_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01131_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01145_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01145_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01145_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01146_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01167_study46_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01178_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01202_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01205_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01221_study25_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01239_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01239_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01239_study10_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01245_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01262_study10_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01280_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01289_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01325_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01385_study11_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01412_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01414_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01423_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01423_study15_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01444_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01453_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01460_study10_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01472_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01481_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01484_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01485_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01503_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01554_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01577_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01595_study18_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01609_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01609_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01624_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01624_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01643_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01645_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01663_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01785_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01812_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01817_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01826_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01893_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01910_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01911_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01945_study12_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01981_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient01984_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02003_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02009_study16_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02084_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02086_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02146_study19_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02195_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02198_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02203_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02229_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02244_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02286_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02286_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02288_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02377_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02378_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02395_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02398_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02493_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02505_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02521_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02524_study12_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02532_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02568_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02569_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02644_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02652_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02688_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02692_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02701_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02795_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02810_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02867_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02878_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02953_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient02962_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03006_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03008_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03048_study10_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03070_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03072_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03087_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03138_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03138_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03230_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03271_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03286_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03296_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03306_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03312_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03370_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03409_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03410_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03449_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03449_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03449_study14_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03452_study25_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03452_study27_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03453_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03453_study1_view2_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03478_study13_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03503_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03512_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03532_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03532_study16_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03542_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03579_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03579_study4_view2_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03675_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03698_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03701_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03716_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03738_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03765_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03787_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03824_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03922_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03933_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03952_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient03972_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04019_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04024_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04031_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04044_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04044_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04064_study14_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04064_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04066_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04067_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04076_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04091_study10_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04102_study11_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04102_study11_view2_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04146_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04153_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04200_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04217_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04255_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04273_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04284_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04302_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04310_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04310_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04317_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04421_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04421_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04427_study19_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04435_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04438_study12_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04438_study14_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04446_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04462_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04529_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04549_study12_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04563_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04568_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04607_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04614_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04620_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04660_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04702_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04702_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04702_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04721_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04723_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04738_study13_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04751_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04754_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04756_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04758_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04760_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04778_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04842_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04845_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04854_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04864_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04879_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04919_study11_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04949_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04949_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04968_study11_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04968_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04973_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient04982_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05023_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05039_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05068_study29_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05094_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05094_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05109_study28_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05140_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05150_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05155_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05164_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05189_study22_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05211_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05234_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05268_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05274_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05316_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05330_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05397_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05456_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05459_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05483_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05497_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05497_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05519_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05534_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05550_study13_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05550_study12_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05582_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05589_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05610_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05626_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05646_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05676_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05706_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05733_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05735_study21_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05804_study18_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05804_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05822_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05834_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05879_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05933_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05954_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient05980_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06057_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06057_study19_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06057_study18_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06059_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06064_study10_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06064_study14_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06064_study15_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06064_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06082_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06084_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06084_study1_view2_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06090_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06090_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06091_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06091_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06154_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06193_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06195_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06204_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06209_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06236_study23_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06319_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06338_study21_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06357_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06364_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06389_study13_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06405_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06420_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06427_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06434_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06435_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06459_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06464_study14_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06464_study15_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06506_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06516_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06516_study14_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06578_study26_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06578_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06580_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06588_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06654_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06693_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06714_study11_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06714_study12_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06780_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06802_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06814_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06829_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06845_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06866_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06931_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06938_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06949_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06959_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06977_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient06978_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07003_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07028_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07036_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07036_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07079_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07083_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07084_study10_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07084_study19_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07111_study11_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07111_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07115_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07163_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07182_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07225_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07239_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07267_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07339_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07378_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07378_study7_view2_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07445_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07488_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07506_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07513_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07513_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07525_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07530_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07547_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07578_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07585_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07645_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07759_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07759_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07781_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07791_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07819_study10_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07819_study11_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07931_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07945_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07945_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07953_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07961_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07972_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07974_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient07975_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08046_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08046_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08112_study10_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08112_study12_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08167_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08184_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08212_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08229_study16_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08229_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08229_study17_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08324_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08379_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08417_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08423_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08450_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08455_study14_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08456_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08478_study14_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08478_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08487_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08549_study32_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08589_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08620_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08661_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08700_study12_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08747_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08765_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08765_study2_view2_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08771_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08782_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08829_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08891_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08901_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08935_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08938_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08941_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08945_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08951_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient08977_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09005_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09010_study11_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09010_study10_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09052_study20_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09133_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09141_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09172_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09178_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09193_study20_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09193_study17_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09226_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09229_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09271_study16_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09286_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09324_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09340_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09354_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09354_study5_view2_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09354_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09362_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09377_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09404_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09452_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09461_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09473_study11_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09514_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09520_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09521_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09522_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09523_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09530_study12_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09572_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09613_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09617_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09653_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09668_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09694_study12_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09739_study11_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09751_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09758_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09760_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09888_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09906_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09913_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09957_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09962_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09981_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient09981_study11_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10025_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10034_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10039_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10054_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10080_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10105_study13_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10128_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10132_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10139_study38_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10140_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10168_study10_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10168_study15_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10174_study12_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10174_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10189_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10199_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10209_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10321_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10345_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10382_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10434_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10465_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10470_study15_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10501_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10562_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10607_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10626_study21_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10664_study11_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10728_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10799_study10_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10799_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10801_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10801_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10867_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10870_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10873_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10895_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10942_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10963_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10967_study19_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10970_study53_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient10980_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11010_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11027_study10_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11030_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11032_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11068_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11087_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11091_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11096_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11106_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11120_study15_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11139_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11151_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11156_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11166_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11242_study24_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11274_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11292_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11302_study13_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11341_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11369_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11389_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11391_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11406_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11452_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11481_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11493_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11525_study12_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11525_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11555_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11582_study21_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11582_study20_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11606_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11647_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11650_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11665_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11696_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11723_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11749_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11763_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11786_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11825_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11840_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11859_study15_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11895_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11998_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient11998_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12004_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12050_study12_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12055_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12064_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12222_study13_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12246_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12294_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12295_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12304_study14_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12316_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12330_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12349_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12349_study16_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12412_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12412_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12431_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12441_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12448_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12488_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12490_study12_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12526_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12526_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12548_study11_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12706_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12709_study21_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12713_study12_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12713_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12753_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12809_study20_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12832_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12836_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12864_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12871_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12877_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12880_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12907_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12954_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12961_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12962_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12963_study24_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient12987_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13041_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13099_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13100_study18_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13102_study10_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13109_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13128_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13162_study40_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13162_study32_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13162_study33_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13187_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13187_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13196_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13225_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13234_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13234_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13248_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13303_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13317_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13338_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13372_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13391_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13418_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13420_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13439_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13531_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13538_study10_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13552_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13625_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13625_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13648_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13658_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13676_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13683_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13683_study5_view2_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13702_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13738_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13745_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13764_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13764_study9_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13849_study34_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13849_study16_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13850_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13862_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13887_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13947_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13954_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13983_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient13984_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14025_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14093_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14097_study13_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14097_study11_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14148_study14_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14148_study12_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14148_study15_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14148_study16_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14175_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14190_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14195_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14283_study12_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14283_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14299_study11_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14332_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14342_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14343_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14352_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14357_study18_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14363_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14371_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14380_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14407_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14407_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14441_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14485_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14486_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14505_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14572_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14589_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14644_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14662_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14707_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14785_study14_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14785_study17_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14807_study17_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14832_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14837_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14940_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient14969_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient15000_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient15006_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient15033_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient15124_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient15163_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient15174_study10_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient15186_study8_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient15186_study11_view1_frontal.jpg
# ...
# ../datasets/dot_90/imgs/train_patient53330_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53340_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53378_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53388_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53413_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53457_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53481_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53514_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53531_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53531_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53627_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53773_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53800_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53868_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53871_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53889_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53926_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53926_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53954_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53968_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53973_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient53993_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient54186_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient54345_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient54432_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient54481_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient54520_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient54572_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient54584_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient54605_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient54633_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient54672_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient54688_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient54704_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient54727_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient54759_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient54789_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient54875_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient54981_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient54988_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55012_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55046_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55079_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55111_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55186_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55217_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55266_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55285_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55316_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55329_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55347_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55374_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55404_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55426_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55436_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55469_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55473_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55478_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55555_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55571_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55594_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55665_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55715_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55736_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55737_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55758_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55771_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55796_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55826_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55889_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55915_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient55923_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56007_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56041_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56041_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56081_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56092_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56139_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56149_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56264_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56279_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56330_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56330_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56343_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56351_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56365_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56370_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56370_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56402_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56406_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56474_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56496_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56557_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56593_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56736_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56736_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56736_study3_view2_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56798_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56798_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56807_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56884_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56898_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56898_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56918_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56953_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient56956_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57070_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57119_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57120_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57132_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57165_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57175_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57275_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57283_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57329_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57430_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57438_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57458_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57506_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57633_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57667_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57667_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57688_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57689_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57757_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57815_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57847_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57875_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57875_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57875_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57906_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57917_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57919_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57921_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient57987_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient58075_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient58178_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient58395_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient58444_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient58474_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient58590_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient58615_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient58616_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient58644_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient58649_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient58698_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient58745_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient58838_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient58847_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient58865_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient58901_study6_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient58912_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient58928_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59043_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59123_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59206_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59211_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59268_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59302_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59304_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59309_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59344_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59394_study4_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59431_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59472_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59473_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59487_study5_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59490_study7_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59552_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59627_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59639_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59676_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59682_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59684_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59694_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59906_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59919_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59984_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient59989_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient60059_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient60180_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient60184_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient60185_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient60191_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient60234_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient60236_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient60789_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient60847_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient60862_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient60915_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient61242_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient61248_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient61275_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient61289_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient61345_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient61352_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient61354_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient61379_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient61474_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient61612_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient61670_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient61768_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient61863_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient62028_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient62075_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient62134_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient62137_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient62229_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient62275_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient62301_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient62359_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient62373_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient62547_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient62575_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient62584_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient62744_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient62836_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient62855_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient62960_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient63097_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient63284_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient63477_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient63676_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient63878_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient63934_study2_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient64067_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient64279_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient64327_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient64328_study3_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient64353_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient64381_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient64414_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient64507_study1_view1_frontal.jpg
# ../datasets/dot_90/imgs/train_patient64522_study1_view1_frontal.jpg
# Images processed and saved in ../datasets/dot_90/imgs

# %% [markdown]
# # Train / Validation / Test
#
# Here we create our train validation and test set.
# We choosed to use 70% of the data for training, 10% for validation and 20% for test.
#
#
# We add another column to info.csv callled `partition` which shows the set that the subject is a part of.

# %%
import pandas as pd
import numpy as np

# Load your CSV file
csv_file_path = info_path  # Replace with your CSV file path
data = pd.read_csv(csv_file_path)

# Set a random seed for reproducibility
np.random.seed(0)

# Define the partition sizes
train_size = 0.7
val_size = 0.1
# Test size is implicitly defined as the remaining percentage

# Shuffle the data
data = data.sample(frac=1).reset_index(drop=True)

# Calculate the number of samples for each partition
num_samples = len(data)
num_train = int(train_size * num_samples)
num_val = int(val_size * num_samples)

# Assign partitions
data['partition'] = 2  # Default to test
data.iloc[:num_train, data.columns.get_loc('partition')] = 0  # Train
data.iloc[num_train:num_train + num_val, data.columns.get_loc('partition')] = 1  # Validation

# Save the updated DataFrame to a new CSV file
updated_csv_path = info_path   # Replace with your desired output file path
data.to_csv(updated_csv_path, index=False)

print("Updated CSV file with partitions saved to:", updated_csv_path)
# Out:
# Updated CSV file with partitions saved to: ../datasets/dot_90/info.csv

# %% [markdown]
# # Statistics
#
# We run some statistics here to check the number of images in each subgroup

# %%
# calculate number of images in each group
import pandas as pd
import numpy as np

# Load your CSV file
csv_file_path = info_path  # Replace with your CSV file path
data = pd.read_csv(csv_file_path)

# Calculate the number of samples for each group
num_samples = len(data)
num_healthy = len(data[data['Healthy/Unhealthy'] == 1])
num_unhealthy = len(data[data['Healthy/Unhealthy'] == -1])

# Print the results
print(f"Total number of samples: {num_samples}")
print(f"Number of healthy samples: {num_healthy}")
print(f"Number of unhealthy samples: {num_unhealthy}")


# calculate number of images in each `group`

group_0 = data[data['group'] == 0]
group_1 = data[data['group'] == 1]
group_2 = data[data['group'] == 2]
group_3 = data[data['group'] == 3]

g0_0 = len(group_0[group_0['partition']==0])
g0_1 = len(group_0[group_0['partition']==1])
g0_2 = len(group_0[group_0['partition']==2])

g1_0 = len(group_1[group_1['partition']==0])
g1_1 = len(group_1[group_1['partition']==1])
g1_2 = len(group_1[group_1['partition']==2])

g2_0 = len(group_2[group_2['partition']==0])
g2_1 = len(group_2[group_2['partition']==1])
g2_2 = len(group_2[group_2['partition']==2])

g3_0 = len(group_3[group_3['partition']==0])
g3_1 = len(group_3[group_3['partition']==1])
g3_2 = len(group_3[group_3['partition']==2])

print(f"Group 0: Train: {g0_0}, Validation: {g0_1}, Test: {g0_2}")
print(f"Group 1: Train: {g1_0}, Validation: {g1_1}, Test: {g1_2}")
print(f"Group 2: Train: {g2_0}, Validation: {g2_1}, Test: {g2_2}")
print(f"Group 3: Train: {g3_0}, Validation: {g3_1}, Test: {g3_2}")
# Out:
# Total number of samples: 2757
# Number of healthy samples: 553
# Number of unhealthy samples: 2204
# Group 0: Train: 1364, Validation: 191, Test: 407
# Group 1: Train: 57, Validation: 5, Test: 6
# Group 2: Train: 166, Validation: 28, Test: 48
# Group 3: Train: 342, Validation: 51, Test: 92

# %% [markdown]
# # Final Note
#
# You can first create the paritions and then split into subgroups if you want to have balanced subgroups in the test time. This is what we orignially did in the paper for having fairer results.
